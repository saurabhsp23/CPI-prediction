# %%
from stepwise_linear_regressor import StepwiseRegression
import datetime 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from os.path import join
from sklearn.metrics import r2_score, mean_absolute_error,mean_absolute_percentage_error
from sklearn.model_selection import train_test_split, cross_val_score
import statsmodels.api as sm
import pipeline

# %%
# Survey Aggregate data and indicator data
df_agg, df_ind = pipeline.read_and_format_data()
# Smoothing the aggregate survey data
rolling_window_size = 20
df_agg = pipeline.data_filter(df_agg, window_size=rolling_window_size)

# %%
df_ind.columns
# Out:
# Index(['CONSSENT Index', 'CONCCONF Index', 'BASPCCUS Index', 'DELQUS30 Index',
#        'DELQUS90 Index', 'USDECRED Index', 'PCE CYOY Index', 'CPI XYOY Index',
#        'CPI YOY Index', 'NYCNMIIR Index', 'NFP TCH Index', 'AHE TOTL Index',
#        'REALYAHE Index', 'PPIDGROC Index ', 'AUTMUSAG Index',
#        'RCPPTFAV Index'],
#       dtype='object')

# %%
df_ind.describe()
# Out:
#        CONSSENT Index  CONCCONF Index  BASPCCUS Index  DELQUS30 Index  \
# count     6035.000000     6023.000000     5685.000000     5576.000000
# mean        82.792428       93.266744     7546.351418        2.726725
# std         12.689908       24.953262      700.555243        1.467488
# min         50.000000       25.300000     6538.230000        0.780000
# 25%         73.200000       77.000000     6939.470000        1.490000
# 50%         84.900000       97.400000     7252.050000        2.240000
# 75%         93.100000      109.900000     8029.960000        3.980000
# max        107.600000      142.500000     9228.380000        5.870000
#
#        DELQUS90 Index  USDECRED Index  PCE CYOY Index  CPI XYOY Index  \
# count     4490.000000     6010.000000     6023.000000     6023.000000
# mean         1.181717        3.447459        2.026711        2.323244
# std          0.748508        1.279386        1.016602        1.146110
# min          0.360000        1.550000        0.625590        0.600000
# 25%          0.700000        2.390000        1.503110        1.700000
# 50%          0.790000        3.060000        1.744720        2.100000
# 75%          1.610000        4.530000        2.107510        2.400000
# max          3.100000        6.770000        5.574700        6.600000
#
#        CPI YOY Index  NFP TCH Index  AHE TOTL Index  REALYAHE Index  \
# count    6023.000000    6023.000000     4576.000000     4315.000000
# mean        2.535348      87.588909       25.483455        3.011101
# std         1.830371    1318.186961        3.654494        1.177887
# min        -2.100000  -20514.000000       20.040000        0.600000
# 25%         1.500000      40.000000       22.590000        2.100000
# 50%         2.200000     158.000000       24.660000        2.700000
# 75%         3.400000     256.000000       27.790000        3.400000
# max         9.100000    4565.000000       33.880000        8.100000
#
#        PPIDGROC Index   AUTMUSAG Index  RCPPTFAV Index
# count      5163.000000     4715.000000     2162.000000
# mean        148.095101        3.172520       39.808788
# std          30.510297        0.657132        3.725056
# min         100.000000        1.880000       22.700000
# 25%         123.100000        2.650000       38.700000
# 50%         142.400000        3.030000       41.000000
# 75%         168.900000        3.700000       42.100000
# max         229.842000        5.470000       45.800000

# %%
stepwise_reg = StepwiseRegression(criterion='bic', verbose=True)

# %%
for indicator in df_ind.columns:
    # Get the combined monthly survey data with indicator data
    print(f"Indicator: {indicator}")
    if pd.api.types.is_numeric_dtype(df_ind[indicator]):
        df_comb = pipeline.get_combined_data_with_given_indicator(df_ind, df_agg, indicator_col=indicator)
        # further modification needed
        df_comb = df_comb.dropna(axis=1)
        if df_comb.shape[1] == 0:
            print('NaN Handling Error')
            continue
        print("Stepwise Linear Model:")
        pipeline.run_model(df_comb, lookback_period=12, model=stepwise_reg)
        print('\n')
# Out:
# Indicator: CONSSENT Index
# Stepwise Linear Model:
# Adding feature 144 to the model
# Adding feature 200 to the model
# Adding feature 51 to the model
# Adding feature 209 to the model
# Adding feature 128 to the model
# Adding feature 198 to the model
# Adding feature 172 to the model
# Adding feature 166 to the model
# Adding feature 9 to the model
# Adding feature 39 to the model
# Adding feature 10 to the model
# Adding feature 60 to the model
# Adding feature 144 to the model
# Adding feature 212 to the model
# Adding feature 143 to the model
# Adding feature 151 to the model
# Adding feature 83 to the model
# Adding feature 9 to the model
# Adding feature 51 to the model
# Adding feature 200 to the model
# Adding feature 279 to the model
# Adding feature 39 to the model
# Adding feature 60 to the model
# Adding feature 171 to the model
# Adding feature 249 to the model
# Adding feature 189 to the model
# Adding feature 16 to the model
# Adding feature 63 to the model
# Adding feature 264 to the model
# Adding feature 144 to the model
# Adding feature 200 to the model
# Adding feature 128 to the model
# Adding feature 124 to the model
# Adding feature 169 to the model
# Adding feature 84 to the model
# Adding feature 249 to the model
# Adding feature 264 to the model
# Adding feature 145 to the model
# Adding feature 63 to the model
# Adding feature 212 to the model
# Adding feature 53 to the model
# Adding feature 10 to the model
# Adding feature 148 to the model
# Adding feature 189 to the model
# Adding feature 141 to the model
# Adding feature 208 to the model
# Adding feature 10 to the model
# Adding feature 280 to the model
# Adding feature 200 to the model
# Adding feature 164 to the model
# Adding feature 243 to the model
# Adding feature 203 to the model
# Adding feature 11 to the model
# Adding feature 90 to the model
# Adding feature 115 to the model
# Adding feature 72 to the model
# Adding feature 228 to the model
# Adding feature 110 to the model
# Adding feature 107 to the model
# Adding feature 262 to the model
# Adding feature 86 to the model
# Adding feature 249 to the model
# Adding feature 87 to the model
# Adding feature 261 to the model
# Adding feature 254 to the model
# Adding feature 265 to the model
# Adding feature 185 to the model
# Adding feature 277 to the model
# Adding feature 215 to the model
# Adding feature 154 to the model
# Adding feature 143 to the model
# Adding feature 191 to the model
# Adding feature 149 to the model
# Adding feature 230 to the model
# Adding feature 212 to the model
# Adding feature 32 to the model
# Adding feature 15 to the model
# Adding feature 201 to the model
# Adding feature 88 to the model
# Adding feature 215 to the model
# Adding feature 87 to the model
# Adding feature 153 to the model
# Adding feature 280 to the model
# Adding feature 262 to the model
# Adding feature 187 to the model
# Adding feature 50 to the model
# Adding feature 84 to the model
# Adding feature 280 to the model
# Adding feature 44 to the model
# Adding feature 24 to the model
# Adding feature 133 to the model
# Adding feature 215 to the model
# Adding feature 264 to the model
# Adding feature 15 to the model
# Adding feature 226 to the model
# Adding feature 210 to the model
# Adding feature 231 to the model
# Adding feature 209 to the model
# Adding feature 146 to the model
# Adding feature 64 to the model
# Adding feature 37 to the model
# Adding feature 153 to the model
# Adding feature 152 to the model
# Adding feature 109 to the model
# Adding feature 215 to the model
# Adding feature 138 to the model
# Adding feature 55 to the model
# Adding feature 173 to the model
# Adding feature 246 to the model
# Adding feature 130 to the model
# Adding feature 101 to the model
# Adding feature 201 to the model
# Adding feature 154 to the model
# Adding feature 221 to the model
# Adding feature 161 to the model
# Adding feature 54 to the model
# Adding feature 100 to the model
# Adding feature 165 to the model
# Adding feature 157 to the model
# Adding feature 175 to the model
# Adding feature 205 to the model
# Adding feature 145 to the model
# Adding feature 160 to the model
# Adding feature 17 to the model
# Adding feature 37 to the model
# Adding feature 37 to the model
# Adding feature 176 to the model
# Adding feature 90 to the model
# Adding feature 33 to the model
# Adding feature 153 to the model
# Adding feature 97 to the model
# Adding feature 130 to the model
# Adding feature 103 to the model
# Adding feature 202 to the model
# Adding feature 57 to the model
# Adding feature 161 to the model
# Adding feature 167 to the model
# Adding feature 86 to the model
# Adding feature 107 to the model
# Adding feature 206 to the model
# Adding feature 234 to the model
# Adding feature 279 to the model
# Adding feature 22 to the model
# Adding feature 242 to the model
# Adding feature 188 to the model
# Adding feature 12 to the model
# Adding feature 143 to the model
# Adding feature 258 to the model
# Adding feature 128 to the model
# Adding feature 167 to the model
# Adding feature 69 to the model
# Adding feature 66 to the model
# Adding feature 177 to the model
# Adding feature 31 to the model
# Adding feature 5 to the model
# Adding feature 119 to the model
# Adding feature 31 to the model
# Adding feature 242 to the model
# Adding feature 147 to the model
# Adding feature 134 to the model
# Adding feature 200 to the model
# Adding feature 223 to the model
# Adding feature 39 to the model
# Adding feature 259 to the model
# Adding feature 178 to the model
# Adding feature 173 to the model
# Adding feature 161 to the model
# Adding feature 222 to the model
# Adding feature 140 to the model
# Adding feature 279 to the model
# Adding feature 96 to the model
# Adding feature 104 to the model
# Adding feature 97 to the model
# Adding feature 20 to the model
# Adding feature 151 to the model
# Adding feature 102 to the model
# Adding feature 150 to the model
# Adding feature 213 to the model
# Adding feature 145 to the model
# Adding feature 177 to the model
# Adding feature 113 to the model
# Adding feature 27 to the model
# Adding feature 32 to the model
# Adding feature 5 to the model
# Adding feature 104 to the model
# Adding feature 180 to the model
# Adding feature 107 to the model
# Adding feature 161 to the model
# Adding feature 118 to the model
# Adding feature 229 to the model
# Adding feature 116 to the model
# Adding feature 148 to the model
# Adding feature 90 to the model
# Adding feature 33 to the model
# Adding feature 111 to the model
# Adding feature 184 to the model
# Adding feature 92 to the model
# Adding feature 173 to the model
# Adding feature 142 to the model
# Adding feature 118 to the model
# Adding feature 179 to the model
# Adding feature 186 to the model
# Adding feature 33 to the model
# Adding feature 45 to the model
# Adding feature 173 to the model
# Adding feature 143 to the model
# Adding feature 218 to the model
# Adding feature 180 to the model
# Adding feature 5 to the model
# Adding feature 92 to the model
# Adding feature 20 to the model
# Adding feature 30 to the model
# Adding feature 208 to the model
# Adding feature 77 to the model
# Adding feature 74 to the model
# Adding feature 80 to the model
# Adding feature 112 to the model
# Adding feature 57 to the model
# Adding feature 161 to the model
# Adding feature 162 to the model
# Adding feature 251 to the model
# Adding feature 8 to the model
# Adding feature 60 to the model
# Adding feature 102 to the model
# Adding feature 233 to the model
# Adding feature 176 to the model
# Adding feature 246 to the model
# Adding feature 127 to the model
# Adding feature 57 to the model
# Adding feature 146 to the model
# Adding feature 121 to the model
# Adding feature 160 to the model
# Adding feature 46 to the model
# Adding feature 177 to the model
# Adding feature 146 to the model
# Adding feature 191 to the model
# Adding feature 134 to the model
# Adding feature 175 to the model
# Adding feature 204 to the model
# Adding feature 112 to the model
# Adding feature 121 to the model
# Adding feature 26 to the model
# Adding feature 71 to the model
# Adding feature 119 to the model
# Adding feature 117 to the model
# Adding feature 180 to the model
# Adding feature 78 to the model
# Adding feature 49 to the model
# Adding feature 14 to the model
# Adding feature 242 to the model
# Adding feature 189 to the model
# Adding feature 35 to the model
# Adding feature 179 to the model
# Adding feature 204 to the model
# Adding feature 129 to the model
# Adding feature 134 to the model
# Adding feature 153 to the model
# Adding feature 5 to the model
# Adding feature 111 to the model
# Adding feature 147 to the model
# Adding feature 129 to the model
# Adding feature 95 to the model
# Adding feature 176 to the model
# Adding feature 134 to the model
# Adding feature 9 to the model
# Adding feature 211 to the model
# Adding feature 112 to the model
# Adding feature 111 to the model
# Adding feature 15 to the model
# Adding feature 40 to the model
# Adding feature 113 to the model
# Adding feature 160 to the model
# Adding feature 190 to the model
# Adding feature 2 to the model
# Adding feature 129 to the model
# Adding feature 132 to the model
# Adding feature 80 to the model
# Adding feature 119 to the model
# Adding feature 147 to the model
# Adding feature 246 to the model
# Adding feature 43 to the model
# Adding feature 261 to the model
# Adding feature 160 to the model
# Adding feature 126 to the model
# Adding feature 4 to the model
# Adding feature 15 to the model
# Adding feature 120 to the model
# Adding feature 265 to the model
# Adding feature 119 to the model
# Adding feature 121 to the model
# Adding feature 131 to the model
# Adding feature 136 to the model
# Adding feature 226 to the model
# Adding feature 232 to the model
# Adding feature 254 to the model
# Adding feature 31 to the model
# Adding feature 224 to the model
# Adding feature 261 to the model
# Adding feature 260 to the model
# Adding feature 186 to the model
# Adding feature 43 to the model
# Adding feature 158 to the model
# Adding feature 234 to the model
# Adding feature 5 to the model
# Adding feature 212 to the model
# Adding feature 184 to the model
# Adding feature 17 to the model
# Adding feature 94 to the model
# Adding feature 277 to the model
# Adding feature 260 to the model
# Adding feature 275 to the model
# Adding feature 129 to the model
# Adding feature 94 to the model
# Adding feature 84 to the model
# Adding feature 42 to the model
# Adding feature 184 to the model
# Adding feature 136 to the model
# Adding feature 57 to the model
# Adding feature 158 to the model
# Adding feature 278 to the model
# Adding feature 260 to the model
# Adding feature 138 to the model
# Adding feature 211 to the model
# Adding feature 263 to the model
# Adding feature 277 to the model
# Adding feature 6 to the model
# Adding feature 10 to the model
# Adding feature 5 to the model
# Adding feature 179 to the model
# Adding feature 264 to the model
# Adding feature 270 to the model
# Adding feature 263 to the model
# Adding feature 6 to the model
# Adding feature 10 to the model
# Adding feature 138 to the model
# Adding feature 277 to the model
# Adding feature 5 to the model
# Adding feature 211 to the model
# Adding feature 179 to the model
# Adding feature 123 to the model
# Adding feature 264 to the model
# Adding feature 151 to the model
# Adding feature 127 to the model
# Adding feature 105 to the model
# Adding feature 214 to the model
# Adding feature 180 to the model
# Adding feature 171 to the model
# Adding feature 5 to the model
# Adding feature 24 to the model
# Adding feature 64 to the model
# Adding feature 36 to the model
# Adding feature 154 to the model
# Adding feature 100 to the model
# Adding feature 277 to the model
# Adding feature 119 to the model
# Adding feature 184 to the model
# Adding feature 252 to the model
# Adding feature 182 to the model
# Adding feature 172 to the model
# Adding feature 132 to the model
# Adding feature 143 to the model
# Adding feature 106 to the model
# Adding feature 84 to the model
# Adding feature 5 to the model
# Adding feature 227 to the model
# Adding feature 165 to the model
# Adding feature 270 to the model
# Adding feature 198 to the model
# Adding feature 219 to the model
# Adding feature 0 to the model
# Adding feature 186 to the model
# Adding feature 79 to the model
# Adding feature 165 to the model
# Adding feature 255 to the model
# Adding feature 41 to the model
# Adding feature 179 to the model
# Adding feature 244 to the model
# Adding feature 263 to the model
# Adding feature 164 to the model
# Adding feature 71 to the model
# Adding feature 158 to the model
# Adding feature 137 to the model
# Adding feature 168 to the model
# Adding feature 71 to the model
# Adding feature 255 to the model
# Adding feature 126 to the model
# Adding feature 244 to the model
# Adding feature 100 to the model
# Adding feature 206 to the model
# Adding feature 186 to the model
# Adding feature 267 to the model
# R-squared: -0.03935572785121755, MAE: 10.070829322325267, MAPE: 0.1398093042865657
#
#
# Indicator: CONCCONF Index
# NaN Handling Error
# Indicator: BASPCCUS Index
# NaN Handling Error
# Indicator: DELQUS30 Index
# NaN Handling Error
# Indicator: DELQUS90 Index
# NaN Handling Error
# Indicator: USDECRED Index
# NaN Handling Error
# Indicator: PCE CYOY Index
# NaN Handling Error
# Indicator: CPI XYOY Index
# NaN Handling Error
# Indicator: CPI YOY Index
# NaN Handling Error
# Indicator: NYCNMIIR Index
# Indicator: NFP TCH Index
# NaN Handling Error
# Indicator: AHE TOTL Index
# NaN Handling Error
# Indicator: REALYAHE Index
# NaN Handling Error
# Indicator: PPIDGROC Index
# NaN Handling Error
# Indicator: AUTMUSAG Index
# NaN Handling Error
# Indicator: RCPPTFAV Index
# NaN Handling Error
