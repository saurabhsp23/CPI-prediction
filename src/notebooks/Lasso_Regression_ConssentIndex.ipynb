# %%
import datetime 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from os.path import join
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error,mean_absolute_percentage_error
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import statsmodels.api as sm
import pipeline

# %%
# Survey Aggregate data and indicator data
df_agg, df_ind = pipeline.read_and_format_data()
# Smoothing the aggregate survey data
rolling_window_size = 20
df_agg = pipeline.data_filter(df_agg, window_size=rolling_window_size)

# %%
DATA_BASE_PATH = '../Data'
df_meta = pd.read_parquet(join(DATA_BASE_PATH,'meta.pq')) 
df_raw = pd.read_parquet(join(DATA_BASE_PATH,'raw.pq'))

# %%
df_meta.head()
# Out:
#     questionid  answerid               category            subcategory  \
# 69          96      1109  Household Information         Home Ownership
# 70          96      1110  Household Information         Home Ownership
# 71          96      1111  Household Information         Home Ownership
# 72          97      1119  Household Information  Home Value Prediction
# 73          97      1120  Household Information  Home Value Prediction
#
#                         tag  \
# 69           Home Ownership
# 70           Home Ownership
# 71           Home Ownership
# 72  Home Value in 12 Months
# 73  Home Value in 12 Months
#
#                                          questiontext  alpharocquestionbank  \
# 69                      Do you own or rent your home?                 False
# 70                      Do you own or rent your home?                 False
# 71                      Do you own or rent your home?                 False
# 72  [ASKED OF HOME OWNERS] What do you expect to h...                 False
# 73  [ASKED OF HOME OWNERS] What do you expect to h...                 False
#
#     alpharocpermanent  is_multiselect  answerordershuffle  \
# 69              False           False               False
# 70              False           False               False
# 71              False           False               False
# 72              False           False               False
# 73              False           False               False
#
#     hasdisplaydependencies                                          showrules  \
# 69                    True                                               <NA>
# 70                    True                                               <NA>
# 71                    True                                               <NA>
# 72                   False  {'atom': {'type': '3', 'type_human': 'previous...
# 73                   False  {'atom': {'type': '3', 'type_human': 'previous...
#
#    parents  answerorder                                         answertext
# 69                    1                                                Own
# 70                    2                                               Rent
# 71                    3  I live in a home that someone else, besides me...
# 72      96            1                            I expect it to increase
# 73      96            2                     I expect it to remain the same

# %%
df_raw.head()
# Out:
#                                  datesubmitted    age  gender   race  \
# respondentid
# 002bd51e1d7497190e6d8d94e099d05f    2019-07-23    65+  Female  White
# aa2f797bfdc8adaad44041a304703a69    2019-07-23  45-64    Male  White
# c1c737ef955f531fbd7a61bfa8830fb7    2019-07-23  30-44    Male  White
# b470df5c9350c78512f1fa26490812e7    2019-07-23    65+  Female  White
# aa284c0e4f729c29ff449f9b95b0eee3    2019-07-23    65+    Male  White
#
#                                  householdincome                 education  \
# respondentid
# 002bd51e1d7497190e6d8d94e099d05f      $50k-$100k         No college degree
# aa2f797bfdc8adaad44041a304703a69         $0-$50k         No college degree
# c1c737ef955f531fbd7a61bfa8830fb7          $150k+  College degree or higher
# b470df5c9350c78512f1fa26490812e7         $0-$50k         No college degree
# aa284c0e4f729c29ff449f9b95b0eee3      $50k-$100k  College degree or higher
#
#                                  urbandensity         partisanship  \
# respondentid
# 002bd51e1d7497190e6d8d94e099d05f        Rural   Modeled Republican
# aa2f797bfdc8adaad44041a304703a69        Rural   Modeled Republican
# c1c737ef955f531fbd7a61bfa8830fb7        Rural  Modeled Swing Voter
# b470df5c9350c78512f1fa26490812e7        Urban   Modeled Republican
# aa284c0e4f729c29ff449f9b95b0eee3      Exurban   Modeled Republican
#
#                                  censusregion      censusdivision  ...  \
# respondentid                                                       ...
# 002bd51e1d7497190e6d8d94e099d05f         West            Mountain  ...
# aa2f797bfdc8adaad44041a304703a69        South  West South Central  ...
# c1c737ef955f531fbd7a61bfa8830fb7        South  West South Central  ...
# b470df5c9350c78512f1fa26490812e7    Northeast     Middle Atlantic  ...
# aa284c0e4f729c29ff449f9b95b0eee3         West             Pacific  ...
#
#                                  Q3053A8020  Q3053A8021  Q3053A8022  \
# respondentid
# 002bd51e1d7497190e6d8d94e099d05f          0           0           0
# aa2f797bfdc8adaad44041a304703a69          0           0           0
# c1c737ef955f531fbd7a61bfa8830fb7          0           0           0
# b470df5c9350c78512f1fa26490812e7          0           0           0
# aa284c0e4f729c29ff449f9b95b0eee3          0           0           0
#
#                                   Q3053A8023  Q3053A8024  Q3053A8025  \
# respondentid
# 002bd51e1d7497190e6d8d94e099d05f           0           0           0
# aa2f797bfdc8adaad44041a304703a69           0           0           0
# c1c737ef955f531fbd7a61bfa8830fb7           0           0           0
# b470df5c9350c78512f1fa26490812e7           0           0           0
# aa284c0e4f729c29ff449f9b95b0eee3           0           0           0
#
#                                   Q3053A8026  Q3053A8027  Q3053A8028  \
# respondentid
# 002bd51e1d7497190e6d8d94e099d05f           0           0           0
# aa2f797bfdc8adaad44041a304703a69           0           0           0
# c1c737ef955f531fbd7a61bfa8830fb7           0           0           0
# b470df5c9350c78512f1fa26490812e7           0           0           0
# aa284c0e4f729c29ff449f9b95b0eee3           0           0           0
#
#                                   Q3053A8029
# respondentid
# 002bd51e1d7497190e6d8d94e099d05f           0
# aa2f797bfdc8adaad44041a304703a69           0
# c1c737ef955f531fbd7a61bfa8830fb7           0
# b470df5c9350c78512f1fa26490812e7           0
# aa284c0e4f729c29ff449f9b95b0eee3           0
#
# [5 rows x 1242 columns]

# %%
indicator = "CONSSENT Index"
print(f"Indicator: {indicator}")
if pd.api.types.is_numeric_dtype(df_ind[indicator]):
    df_comb = pipeline.get_combined_data_with_given_indicator(df_ind, df_agg, indicator_col=indicator)
    df_comb = df_comb.dropna(axis=1,how='all').bfill().ffill()
    print(df_comb.shape)
    X = df_comb.iloc[:,:-1]
    y = df_comb.iloc[:,-1]
    y = (y - np.mean(y))/np.std(y)
# Out:
# Indicator: CONSSENT Index
# (49, 1231)

# %%
df = df_comb

# %%
# Assuming df is your DataFrame
X = df.drop('CONSSENT Index', axis=1)
y = df['CONSSENT Index']

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Fit Lasso model
alpha = 0.01  # Tune this parameter
lasso = Lasso(alpha=alpha)
lasso.fit(X_train, y_train)

# Get coefficients and pair with feature names
coefficients = lasso.coef_
features = X.columns
feature_importance = pd.Series(coefficients, index=features)

# Sort features by importance
important_features = feature_importance.abs().sort_values(ascending=False)


# Filter out zero coefficients
important_features = important_features[important_features > 0][:50]
# print("Sorted Important Features:")
# print(important_features)
# Function to extract question and answer numbers and texts
def extract_qa_info(feature_name, df_meta):
    q_parts = feature_name.split('A')
    q_id = int(q_parts[0][1:])
    a_id = int(q_parts[1])
    
    if q_id not in df_meta['questionid'].values:
        return -1, a_id, "Question ID not found", "N/A"
    
    if a_id not in df_meta['answerid'].values:
        return -1, a_id, "N/A", "Answer ID not found"
    
    q_text = df_meta.loc[df_meta['questionid'] == q_id, 'questiontext'].values[0]
    a_text = df_meta.loc[df_meta['answerid'] == a_id, 'answertext'].values[0]
    
    return q_id, a_id, q_text, a_text

# Extracting question and answer numbers and texts
print("\nQuestion and Answer Details:")
for feature in important_features.index:
    q_id, a_id, q_text, a_text = extract_qa_info(feature, df_meta)
    if q_id != -1:
        print(f"Feature: {feature}, Question ID: {q_id}, Answer ID: {a_id}, Question Text: {q_text}, Answer Text: {a_text}")
# Out:
# Question and Answer Details:
# Feature: Q585A1085, Question ID: 585, Answer ID: 1085, Question Text: Thinking about business in the country as a whole, do you think that during the next 12 months we'll have good times or bad times financially?, Answer Text: Good times
# Feature: Q585A1087, Question ID: 585, Answer ID: 1087, Question Text: Thinking about business in the country as a whole, do you think that during the next 12 months we'll have good times or bad times financially?, Answer Text: Not sure
# Feature: Q340A1072, Question ID: 340, Answer ID: 1072, Question Text: Six months from now, do you think business conditions in the United States will be...?, Answer Text: Worse than they are now
# Feature: Q585A1086, Question ID: 585, Answer ID: 1086, Question Text: Thinking about business in the country as a whole, do you think that during the next 12 months we'll have good times or bad times financially?, Answer Text: Bad times
# Feature: Q173A1287, Question ID: 173, Answer ID: 1287, Question Text: [How often do you shop at each of the following online retailers?] Ebay.com, Answer Text: About once per week
# Feature: Q153A1251, Question ID: 153, Answer ID: 1251, Question Text: [How often do you shop at each of the following stores, either in store or online?] Walmart / walmart.com, Answer Text: About once per week
# Feature: Q183A1395, Question ID: 183, Answer ID: 1395, Question Text: One year from now, what percentage of your shopping dollars do you think you will spend online versus in physical stores?, Answer Text: 70% Online / 30% Physical Stores
# Feature: Q154A1251, Question ID: 154, Answer ID: 1251, Question Text: [How often do you shop at each of the following stores, either in store or online?] Target / target.com, Answer Text: About once per week
# Feature: Q597A1808, Question ID: 597, Answer ID: 1808, Question Text: Has your employment status been affected by the coronavirus outbreak?, Answer Text: Yes, I've been laid off / furloughed
# Feature: Q159A1252, Question ID: 159, Answer ID: 1252, Question Text: [How often do you shop at each of the following stores, either in store or online?] Family Dollar, Answer Text: A few times per month
# Feature: Q663A1129, Question ID: 663, Answer ID: 1129, Question Text: [ASKED OF RESPONDENTS PLANNING HOME RENOVATIONS] In the next 12 months, how much do you anticipate spending on renovations or improvements to your house?, Answer Text: $1,001-$5,000
# Feature: Q158A1252, Question ID: 158, Answer ID: 1252, Question Text: [How often do you shop at each of the following stores, either in store or online?] Dollar General / dollargeneral.com, Answer Text: A few times per month
# Feature: Q101A1116, Question ID: 101, Answer ID: 1116, Question Text: [ASKED OF HOME OWNERS] In the next 12 months, do you anticipate...?, Answer Text: Selling your current home and moving to a smaller home
# Feature: Q156A1251, Question ID: 156, Answer ID: 1251, Question Text: [How often do you shop at each of the following stores, either in store or online?] Costco / costco.com, Answer Text: About once per week
# /Users/shivam/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.086e+00, tolerance: 7.258e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
# Assuming df is your DataFrame
X = df.drop('CONSSENT Index', axis=1)
y = df['CONSSENT Index']

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Fit Lasso model
alpha = 0.01  # Tune this parameter
lasso = Lasso(alpha=alpha)
lasso.fit(X_train, y_train)

# Get coefficients and pair with feature names
coefficients = lasso.coef_
features = X.columns
feature_importance = pd.Series(coefficients, index=features)

# Sort features by importance
features_ = feature_importance.abs()

zero_features = features_[features_ == 0][:140]

# Function to extract question and answer numbers and texts
def extract_qa_info(feature_name, df_meta):
    q_parts = feature_name.split('A')
    q_id = int(q_parts[0][1:])
    a_id = int(q_parts[1])
    
    if q_id not in df_meta['questionid'].values:
        return -1, a_id, "Question ID not found", "N/A"
    
    if a_id not in df_meta['answerid'].values:
        return -1, a_id, "N/A", "Answer ID not found"
    
    q_text = df_meta.loc[df_meta['questionid'] == q_id, 'questiontext'].values[0]
    a_text = df_meta.loc[df_meta['answerid'] == a_id, 'answertext'].values[0]
    
    return q_id, a_id, q_text, a_text

# Extracting question and answer numbers and texts
print("\nQuestion and Answer Details:")
for feature in zero_features.index:
    q_id, a_id, q_text, a_text = extract_qa_info(feature, df_meta)
    if q_id != -1:
        print(f"Feature: {feature}, Question ID: {q_id}, Answer ID: {a_id}, Question Text: {q_text}, Answer Text: {a_text}")
# Out:
# Question and Answer Details:
# Feature: Q583A1079, Question ID: 583, Answer ID: 1079, Question Text: Would you say that you and your family are better off or worse off financially than you were a year ago?, Answer Text: Better off
# Feature: Q583A1080, Question ID: 583, Answer ID: 1080, Question Text: Would you say that you and your family are better off or worse off financially than you were a year ago?, Answer Text: The same today as a year ago
# Feature: Q583A1081, Question ID: 583, Answer ID: 1081, Question Text: Would you say that you and your family are better off or worse off financially than you were a year ago?, Answer Text: Worse off
# Feature: Q584A1082, Question ID: 584, Answer ID: 1082, Question Text: In a year from now, do you think you and your family will be better off financially, worse off financially, or about the same as you are now?, Answer Text: Better off
# Feature: Q584A1083, Question ID: 584, Answer ID: 1083, Question Text: In a year from now, do you think you and your family will be better off financially, worse off financially, or about the same as you are now?, Answer Text: About the same
# Feature: Q584A1084, Question ID: 584, Answer ID: 1084, Question Text: In a year from now, do you think you and your family will be better off financially, worse off financially, or about the same as you are now?, Answer Text: Worse off
# Feature: Q586A1088, Question ID: 586, Answer ID: 1088, Question Text: Looking ahead, which would you say is more likely?, Answer Text: We'll have continuous good times during the next five years or so
# Feature: Q586A1089, Question ID: 586, Answer ID: 1089, Question Text: Looking ahead, which would you say is more likely?, Answer Text: We'll have periods of widespread unemployment or depression during the next five years or so
# Feature: Q586A1090, Question ID: 586, Answer ID: 1090, Question Text: Looking ahead, which would you say is more likely?, Answer Text: Not sure
# Feature: Q587A1093, Question ID: 587, Answer ID: 1093, Question Text: Think about the big things that people buy for their homes, such as furniture, a refrigerator, a stove, or a television. Generally speaking, do you think now is a good or a bad time for people to buy major household items?, Answer Text: Not sure
# Feature: Q595A1208, Question ID: 595, Answer ID: 1208, Question Text: How frequently do you shop for groceries?, Answer Text: Almost every day
# Feature: Q595A1209, Question ID: 595, Answer ID: 1209, Question Text: How frequently do you shop for groceries?, Answer Text: A few times per week
# Feature: Q595A1210, Question ID: 595, Answer ID: 1210, Question Text: How frequently do you shop for groceries?, Answer Text: About once per week
# Feature: Q595A1211, Question ID: 595, Answer ID: 1211, Question Text: How frequently do you shop for groceries?, Answer Text: A few times per month
# Feature: Q595A1212, Question ID: 595, Answer ID: 1212, Question Text: How frequently do you shop for groceries?, Answer Text: About once per month
# Feature: Q595A1213, Question ID: 595, Answer ID: 1213, Question Text: How frequently do you shop for groceries?, Answer Text: A few times per year
# Feature: Q597A1809, Question ID: 597, Answer ID: 1809, Question Text: Has your employment status been affected by the coronavirus outbreak?, Answer Text: No, I am still employed
# Feature: Q597A1810, Question ID: 597, Answer ID: 1810, Question Text: Has your employment status been affected by the coronavirus outbreak?, Answer Text: My hours have been reduced but I am still working
# Feature: Q597A1811, Question ID: 597, Answer ID: 1811, Question Text: Has your employment status been affected by the coronavirus outbreak?, Answer Text: I was laid off, but I have since found another job
# Feature: Q597A1812, Question ID: 597, Answer ID: 1812, Question Text: Has your employment status been affected by the coronavirus outbreak?, Answer Text: I was laid off, but I have since been rehired at my same job
# Feature: Q597A1813, Question ID: 597, Answer ID: 1813, Question Text: Has your employment status been affected by the coronavirus outbreak?, Answer Text: I was not working before the coronavirus outbreak (e.g. retired, disabled, student, homemaker, etc.)
# Feature: Q96A1109, Question ID: 96, Answer ID: 1109, Question Text: Do you own or rent your home?, Answer Text: Own
# Feature: Q96A1110, Question ID: 96, Answer ID: 1110, Question Text: Do you own or rent your home?, Answer Text: Rent
# Feature: Q96A1111, Question ID: 96, Answer ID: 1111, Question Text: Do you own or rent your home?, Answer Text: I live in a home that someone else, besides me, owns
# Feature: Q97A1119, Question ID: 97, Answer ID: 1119, Question Text: [ASKED OF HOME OWNERS] What do you expect to happen to the price of your home in the next 12 months?, Answer Text: I expect it to increase
# Feature: Q97A1120, Question ID: 97, Answer ID: 1120, Question Text: [ASKED OF HOME OWNERS] What do you expect to happen to the price of your home in the next 12 months?, Answer Text: I expect it to remain the same
# Feature: Q98A1122, Question ID: 98, Answer ID: 1122, Question Text: [ASKED OF HOME OWNERS] What do you expect to happen to the price of your home in the next 5 years?, Answer Text: I expect it to increase
# Feature: Q98A1123, Question ID: 98, Answer ID: 1123, Question Text: [ASKED OF HOME OWNERS] What do you expect to happen to the price of your home in the next 5 years?, Answer Text: I expect it to remain the same
# Feature: Q98A1124, Question ID: 98, Answer ID: 1124, Question Text: [ASKED OF HOME OWNERS] What do you expect to happen to the price of your home in the next 5 years?, Answer Text: I expect it to decrease
# Feature: Q100A1125, Question ID: 100, Answer ID: 1125, Question Text: [ASKED OF HOME OWNERS] In the next 12 months, do you anticipate making any renovations or improvements to your house?, Answer Text: Yes, I plan on making major home improvements (e.g. a full kitchen or bath remodel, plumbing or electrical work, building an addition, replacing your roof)
# Feature: Q100A1126, Question ID: 100, Answer ID: 1126, Question Text: [ASKED OF HOME OWNERS] In the next 12 months, do you anticipate making any renovations or improvements to your house?, Answer Text: Yes, I plan on making minor home improvements (e.g. painting, replacing appliances, patio/deck refurbishment)
# Feature: Q100A1127, Question ID: 100, Answer ID: 1127, Question Text: [ASKED OF HOME OWNERS] In the next 12 months, do you anticipate making any renovations or improvements to your house?, Answer Text: No
# Feature: Q101A1114, Question ID: 101, Answer ID: 1114, Question Text: [ASKED OF HOME OWNERS] In the next 12 months, do you anticipate...?, Answer Text: Selling your current home and moving to a larger home
# Feature: Q101A1118, Question ID: 101, Answer ID: 1118, Question Text: [ASKED OF HOME OWNERS] In the next 12 months, do you anticipate...?, Answer Text: Not selling your current home
# Feature: Q103A1168, Question ID: 103, Answer ID: 1168, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Groceries, Answer Text: I expect to spend less
# Feature: Q103A1169, Question ID: 103, Answer ID: 1169, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Groceries, Answer Text: I expect to spend the same amount
# Feature: Q103A1170, Question ID: 103, Answer ID: 1170, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Groceries, Answer Text: I expect to spend more
# Feature: Q104A1168, Question ID: 104, Answer ID: 1168, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Gasoline / Fuel, Answer Text: I expect to spend less
# Feature: Q104A1169, Question ID: 104, Answer ID: 1169, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Gasoline / Fuel, Answer Text: I expect to spend the same amount
# Feature: Q104A1170, Question ID: 104, Answer ID: 1170, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Gasoline / Fuel, Answer Text: I expect to spend more
# Feature: Q105A1168, Question ID: 105, Answer ID: 1168, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Household goods (e.g. toilet paper, cleaning supplies), Answer Text: I expect to spend less
# Feature: Q105A1169, Question ID: 105, Answer ID: 1169, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Household goods (e.g. toilet paper, cleaning supplies), Answer Text: I expect to spend the same amount
# Feature: Q105A1170, Question ID: 105, Answer ID: 1170, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Household goods (e.g. toilet paper, cleaning supplies), Answer Text: I expect to spend more
# Feature: Q106A1168, Question ID: 106, Answer ID: 1168, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Rent / Mortgage, Answer Text: I expect to spend less
# Feature: Q106A1169, Question ID: 106, Answer ID: 1169, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Rent / Mortgage, Answer Text: I expect to spend the same amount
# Feature: Q106A1170, Question ID: 106, Answer ID: 1170, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Rent / Mortgage, Answer Text: I expect to spend more
# Feature: Q107A1168, Question ID: 107, Answer ID: 1168, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Telephone / Wireless, Answer Text: I expect to spend less
# Feature: Q107A1169, Question ID: 107, Answer ID: 1169, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Telephone / Wireless, Answer Text: I expect to spend the same amount
# Feature: Q107A1170, Question ID: 107, Answer ID: 1170, Question Text: [Over the next year, do you expect to spend more or less than you currently do on the following categories?] Telephone / Wireless, Answer Text: I expect to spend more
# /Users/shivam/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.086e+00, tolerance: 7.258e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
# Selecting specific columns
df_selected = df_meta[['questionid', 'questiontext']].drop_duplicates()
# Converting the selected dataframe to a CSV format string
# Index and header are set to False to exclude them from the output
csv_string = df_selected.to_csv(index=False, header=False)
# Printing the CSV string
print(csv_string)
# Out:
# 96,Do you own or rent your home?
# 97,[ASKED OF HOME OWNERS] What do you expect to happen to the price of your home in the next 12 months?
# 98,[ASKED OF HOME OWNERS] What do you expect to happen to the price of your home in the next 5 years?
# 100,"[ASKED OF HOME OWNERS] In the next 12 months, do you anticipate making any renovations or improvements to your house?"
# 101,"[ASKED OF HOME OWNERS] In the next 12 months, do you anticipate...?"
# 103,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] Groceries"
# 104,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] Gasoline / Fuel"
# 105,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] Household goods (e.g. toilet paper, cleaning supplies)"
# 106,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] Rent / Mortgage"
# 107,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] Telephone / Wireless"
# 108,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] TV (cable, satellite) & Internet"
# 109,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] Savings / investing for retirement"
# 110,"[Over the next year, do you expect to spend more or less than you currently do on the following categories?] Dining out"
# 153,"[How often do you shop at each of the following stores, either in store or online?] Walmart / walmart.com"
# 154,"[How often do you shop at each of the following stores, either in store or online?] Target / target.com"
# 155,"[How often do you shop at each of the following stores, either in store or online?] Sam's Club / samsclub.com"
# 156,"[How often do you shop at each of the following stores, either in store or online?] Costco / costco.com"
# 158,"[How often do you shop at each of the following stores, either in store or online?] Dollar General / dollargeneral.com"
# 159,"[How often do you shop at each of the following stores, either in store or online?] Family Dollar"
# 170,[How often do you shop at each of the following online retailers?] Amazon.com
# 173,[How often do you shop at each of the following online retailers?] Ebay.com
# 182,Roughly what percentage of your shopping dollars do you spend online versus in physical stores?
# 183,"One year from now, what percentage of your shopping dollars do you think you will spend online versus in physical stores?"
# 184,At which of the following stores do you shop? Please select all that apply.
# 316,Which of the following best describes your employment situation?
# 335,"Generally speaking, how would you describe your overall financial situation?"
# 337,Which of the following best describes the amount of credit card debt your household currently owes?
# 338,How would you rate business conditions in the United States today?
# 339,How would you rate employment conditions in the United States today?
# 340,"Six months from now, do you think business conditions in the United States will be...?"
# 341,"Six months from now, do you think there will be...?"
# 342,"Six months from now, do you think your household income will...?"
# 583,Would you say that you and your family are better off or worse off financially than you were a year ago?
# 584,"In a year from now, do you think you and your family will be better off financially, worse off financially, or about the same as you are now?"
# 585,"Thinking about business in the country as a whole, do you think that during the next 12 months we'll have good times or bad times financially?"
# 586,"Looking ahead, which would you say is more likely?"
# 587,"Think about the big things that people buy for their homes, such as furniture, a refrigerator, a stove, or a television. Generally speaking, do you think now is a good or a bad time for people to buy major household items?"
# 595,How frequently do you shop for groceries?
# 597,Has your employment status been affected by the coronavirus outbreak?
# 663,"[ASKED OF RESPONDENTS PLANNING HOME RENOVATIONS] In the next 12 months, how much do you anticipate spending on renovations or improvements to your house?"
# 664,Which of the following best describes your current working situation?
# 2400,"Six months from now, how do you think you will describe your overall financial situation?"
# 2401,"One year from now, how do you think you will describe your overall financial situation?"
# 2402,"Six months from now, how satisfied or dissatisfied do you think you will feel about your standard of living?"
# 2403,"One year from now, how satisfied or dissatisfied do you think you will feel about your standard of living?"
# 2406,[ASKED OF FULL TIME EMPLOYED RESPONDENTS] Which of the following best describes you?
# 2407,[ASKED OF FULL TIME HOMEMAKERS AND RESPONDENTS NOT WORKING AND NOT LOOKING FOR WORK] Why are you currently not looking for work? Please select all that apply.
# 2426,Which of the following have you done in the past six months due to inflation or higher prices? Please select all that apply.
# 2427,"If the prices of goods and services continue to increase over the next six months, which of the following will you consider doing? Please select all that apply."
# 2428,How often are you worried or thinking about inflation or rising prices these days?
# 2429,"Thinking about used car prices in general, which of the following is closest to your opinion?"
# 2464,"Six months from now, how do you think the stock market will be doing compared to today?"
# 2465,"Six months from now, what do you think the price of gold will be compared to its price today?"
# 2466,"Six months from now, what do you think the price of Bitcoin will be compared to its price today?"
# 2467,"Six months from now, do you think interest rates will be higher or lower than they are today?"
# 2468,"Over the next six months, do you think we are likely or not likely to enter an economic recession?"
# 2474,"Thinking about new car prices in general, which of the following is closest to your opinion?"
